# %%
# %matplotlib inline
import numpy as np
import scipy as sp
from scipy.stats import multivariate_normal

import matplotlib.pyplot as plt
import seaborn as sns; sns.set_style("darkgrid"); sns.set_context("talk")

import GPy    # a Gaussian Process (GP) framework written in python

# %%
X = np.random.uniform(-3.,3.,(20,1))
Y = np.sin(X) + np.random.randn(20,1)*0.05

# %%
np.shape(X)
# Out:
# (20, 1)

# %%
X = np.array([1,2,3,7,8,9])
X = np.reshape(X, (-1, 1))
Y = np.array([0,.1,.05,-.05,-.1,0])
Y = np.reshape(Y, (-1, 1))

# %%
np.shape(X)
# Out:
# (6, 1)

# %%
#kernel = GPy.kern.RBF(input_dim=1, variance=1., lengthscale=1.)
kernel = GPy.kern.Matern32(1, 0.5, 0.2)

# %%
#type GPy.kern.<tab> here:
#GPy.kern.BasisFuncKernel?

# %%
m = GPy.models.GPRegression(X,Y,kernel)

# %%
display(m)
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 6.7383555372581085<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  Mat32.variance         </td><td class=tg-right>  0.5</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Mat32.lengthscale      </td><td class=tg-right>  0.2</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
fig = m.plot()
#GPy.plotting.show(fig, filename='basic_gp_regression_notebook')
ax=plt.gca()

# %%
m.optimize(messages=True)
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…

# %%
m.optimize_restarts(num_restarts = 10)
# Out:
# Optimization restart 1/10, f = -8.424092635285943
# Optimization restart 2/10, f = -8.424092705211896
# Optimization restart 3/10, f = -8.424092656727641
# Optimization restart 4/10, f = -8.424092701747655
# Optimization restart 5/10, f = -8.424092682138761
# Optimization restart 6/10, f = -8.42409268568144
# Optimization restart 7/10, f = -8.424092708774445
# Optimization restart 8/10, f = -8.42409270156439
# Optimization restart 9/10, f = -8.424092657290798
# Optimization restart 10/10, f = -8.424092689034659
# [<paramz.optimization.optimization.opt_lbfgsb at 0x15f7b8730>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x15fa7cf70>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x10b6a7a00>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x15f8c5f70>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x15f7b8b20>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x15f88e3a0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x15f7fba00>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x15fa749a0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x15fa7c6d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x15f8247c0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x15fa7cca0>]

# %%
display(m)
fig = m.plot(plot_density=False, figsize=(8,6))
#GPy.plotting.show(fig, filename='basic_gp_regression_notebook_optimized')
#fig = m.plot(plot_density=False, figsize=(8,6))
ax=plt.gca()
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -8.424092708774445<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>               value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  Mat32.variance         </td><td class=tg-right>0.003889389661046847</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Mat32.lengthscale      </td><td class=tg-right>  0.8010749187974141</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>8.69615317675179e-10</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>
